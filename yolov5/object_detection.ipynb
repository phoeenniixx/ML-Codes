# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ws1t9PlAbnNC2y6Zs3br")
project = rf.workspace("web-page-summarizer").project("web-page-object-detection")
dataset = project.version(1).download("yolov5")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.0/70.0 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 20.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 9.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
# ...

# %%
import comet_ml
comet_ml.init(project_name='webpage-object-detection')
# Out:
# Please paste your Comet API key from https://www.comet.com/api/my/settings/
# (api key may not show as you type)
# Comet API key: ··········
# COMET INFO: Valid Comet API Key saved in /root/.comet.config (set COMET_CONFIG to change where it is saved).

# %%
# %pip install comet_ml --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.4/599.4 kB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 54.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 27.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 14.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 514.7/514.7 kB 42.4 MB/s eta 0:00:00

# %%
# !git clone https://github.com/tensorflow/tpu/
# Out:
# Cloning into 'tpu'...
# remote: Enumerating objects: 11642, done.
# remote: Counting objects: 100% (1844/1844), done.
# remote: Compressing objects: 100% (835/835), done.
# remote: Total 11642 (delta 1065), reused 1618 (delta 963), pack-reused 9798
# Receiving objects: 100% (11642/11642), 47.06 MiB | 15.87 MiB/s, done.
# Resolving deltas: 100% (8103/8103), done.

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16383, done.
# remote: Counting objects: 100% (277/277), done.
# remote: Compressing objects: 100% (203/203), done.
# remote: Total 16383 (delta 138), reused 158 (delta 74), pack-reused 16106
# Receiving objects: 100% (16383/16383), 15.16 MiB | 11.25 MiB/s, done.
# Resolving deltas: 100% (11175/11175), done.

# %%
import functools
import matplotlib.pyplot as plt
import cv2
import matplotlib.pyplot as plt
from sklearn import preprocessing
from keras.utils import img_to_array

# %%
import sys
sys.path.insert(0, 'tpu/models/official')
sys.path.insert(0, 'tpu/models/official/mask_rcnn')
sys.path.insert(0,'/content/yolov5/models')
from mask_rcnn.object_detection import visualization_utils
import coco_metric

# %%
from IPython import display
from PIL import Image
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
import xml.etree.ElementTree as ET
import torch
import torchvision

from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator

from torch.utils.data import DataLoader, Dataset
from torch.utils.data import SequentialSampler

# %%
# %cd /content/yolov5
# !python train.py --img 640 --epochs 10 --data Web-Page-Object-Detection-1/data.yaml  --cfg ./models/yolov5x.yaml --weights '' --name yolov5s_results  --cache
# Out:
# /content/yolov5
# 2024-01-26 09:34:12.680046: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-26 09:34:12.680102: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-26 09:34:12.681230: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !env COMET_MAX_IMAGE_UPLOADS=200 python train.py \
--img 640 \
--batch 16 \
--epochs 5 \
--data Web-Page-Object-Detection-1/data.yaml \
--weights yolov5s.pt \
--bbox_interval 1
# Out:
# 2024-01-26 09:45:49.629546: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-26 09:45:49.629615: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-26 09:45:49.630908: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import comet_ml; comet_ml.init()

# %%
# !export COMET_API_KEY="VYEGVeYm8nzNSpaEqTJuljWsC"  # 2. paste API key
# !python train.py --img 640 --epochs 10 --data Web-Page-Object-Detection-1/data.yaml  --cfg ./models/yolov5x.yaml --weights '' --name yolov5s_results  --cache
# Out:
# 2024-01-26 10:02:14.637688: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-26 10:02:14.637741: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-26 10:02:14.639027: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
